# %% [markdown]
# Extract DANE

# %%
# Load packages
import pandas as pd
import numpy as np

# %%
SEDE_CARATULA = pd.read_csv("DataDANE/Carátula única sede educativa.csv", sep = ';' , encoding = "ISO-8859-1")


SEDE_PRINCIPAL = pd.read_csv("DataDANE/Sedes_principales_sector oficial.csv", sep = ';' , encoding = "ISO-8859-1")
SEDE_PLANTAS = pd.read_csv("DataDANE/Relación sedes principal y adscrita.csv", sep = ';' , encoding = "ISO-8859-1")
SEDE_ADSCRITA = pd.read_csv("DataDANE/Relación sede principal y adscritas (sector oficial).csv", sep = ';' , encoding = "ISO-8859-1")
GRUPOS_FLEX = pd.read_csv("DataDANE/Número de grupos en modelos educativos flexibles.csv", sep = ';' , encoding = "ISO-8859-1")
SEDE_MATRICULA = pd.read_csv("DataDANE/tipo de matricula propia o contratada, según nivel educativo por jornada.csv", sep = ';' , encoding = "ISO-8859-1")

TIC_CANT = pd.read_csv("DataDANE/Tenencia y número de equipos de cómputo por sede educativa.csv", sep = ';' , encoding = "ISO-8859-1")
TIC_SERVICIOS = pd.read_csv("DataDANE/Tenencia acceso.csv", sep = ';' , encoding = "ISO-8859-1")
# Out:
# /home/ec2-user/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
SEDE_ADSCRITA
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  SEDEADSC_CODIGO  \
# 0        168418000269           6          2019     268418000379
# 1        168418000269           6          2019     268418000344
# 2        168418000269           6          2019     268418000042
# 3        168418000269           6          2019     268418000077
# 4        168418000269           6          2019     268418000433
# ...               ...         ...           ...              ...
# 34281    294001000024           6          2019     294001001373
# 34282    120045000210           6          2019     120045000112
# 34283    205051000758           6          2019     205051001665
# 34284    205051000758           6          2019     205659000254
# 34285    288001000482           6          2019     288001000245
#
#                                        SEDEADSC_NOMBRE  \
# 0                           ESCUELA RURAL LAS DELICIAS
# 1                                ESCUELA RURAL EL POZO
# ...

# %%
SEDE_ADSCRITA_P = SEDE_ADSCRITA[['ï»¿SEDE_CODIGO','SEDEADSC_CODIGO','SEDEADSC_NOMBRE','DEPTO','CODIGOINTERNOMUNI','MUNI','AREA_NOMBRE']]
SEDE_ADSCRITA_P
# Out:
#        ï»¿SEDE_CODIGO  SEDEADSC_CODIGO  \
# 0        168418000269     268418000379
# 1        168418000269     268418000344
# 2        168418000269     268418000042
# 3        168418000269     268418000077
# 4        168418000269     268418000433
# ...               ...              ...
# 34281    294001000024     294001001373
# 34282    120045000210     120045000112
# 34283    205051000758     205051001665
# 34284    205051000758     205659000254
# 34285    288001000482     288001000245
#
#                                        SEDEADSC_NOMBRE  \
# 0                           ESCUELA RURAL LAS DELICIAS
# 1                                ESCUELA RURAL EL POZO
# 2                                ESCUELA RURAL LA PEÑA
# 3                           ESCUELA RURAL EL GARBANZAL
# 4                             ESCUELA RURAL EL GUAMITO
# ...                                                ...
# 34281                      CENTRO EDUCATIVO SAN RAFAEL
# ...

# %%
SEDE_PRINCIPAL
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  SEDEPRINC_CODIGO  \
# 0        225839000300           6          2019      425839001071
# 1        205670000835           6          2019      205670000720
# 2        276130000296           6          2019      276130000822
# 3        205670000029           6          2019      205670000720
# 4        205761000412           6          2019      105761000299
# ...               ...         ...           ...               ...
# 35277    225123000074           6          2019      225123000074
# 35278    250568002021           6          2019      250568002021
# 35279    250568002039           6          2019      250568002039
# 35280    250568800008           6          2019      250568800008
# 35281    250568800091           6          2019      250568800091
#
#                                    SEDEPRINC_NOMBRE  \
# 0                     COLEGIO DEPARTAMENTAL MÁMBITA
# 1                   CENTRO EDUCATIVO RURAL SAN JUAN
# ...

# %%
SEDE_ADSCRITA[SEDE_ADSCRITA['ï»¿SEDE_CODIGO'] == 205670000720]
# Out:
#       ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  SEDEADSC_CODIGO  \
# 7267    205670000720           6          2019     205670000142
# 7268    205670000720           6          2019     205670000193
# 7269    205670000720           6          2019     205670000495
# 7270    205670000720           6          2019     205670000584
# 7271    205670000720           6          2019     205670000258
# 7272    205670000720           6          2019     205670000061
# 7273    205670000720           6          2019     205670000703
# 7274    205670000720           6          2019     205670000690
# 7275    205670000720           6          2019     205670000240
# 7276    205670000720           6          2019     205670000185
# 7277    205670000720           6          2019     205670000223
# 7278    205670000720           6          2019     205670000126
# 7279    205670000720           6          2019     205670000215
# 7280    205670000720           6          2019     205670000428
# ...

# %%
SEDE_PRINCIPAL[SEDE_PRINCIPAL['SEDEPRINC_CODIGO'] == 205670000720]
# Out:
#       ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  SEDEPRINC_CODIGO  \
# 1       205670000835           6          2019      205670000720
# 3       205670000029           6          2019      205670000720
# 277     205670000142           6          2019      205670000720
# 351     205670000304           6          2019      205670000720
# 468     205670000126           6          2019      205670000720
# 585     405670000966           6          2019      205670000720
# 633     205670000266           6          2019      205670000720
# 779     205670000665           6          2019      205670000720
# 823     405670001024           6          2019      205670000720
# 1542    205670000797           6          2019      205670000720
# 1670    405670000940           6          2019      205670000720
# 2000    205670000053           6          2019      205670000720
# 2001    205670000118           6          2019      205670000720
# ...

# %%
#df_suffix = pd.merge(df1, df2, left_on='id',right_on='id',how='outer',suffixes=('_left','_right'))

#df_suffix = pd.merge(SEDE_ADSCRITA, SEDE_PRINCIPAL, left_on='ï»¿SEDE_CODIGO',right_on='SEDEPRINC_CODIGO',how='outer',suffixes=('_left','_right'))
print(SEDE_PRINCIPAL['ï»¿SEDE_CODIGO'].nunique())
print(SEDE_ADSCRITA['SEDEADSC_CODIGO'].nunique())
# Out:
# 35116
# 34286

# %%
SEDE_PLANTAS
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO SEDE_TIPO       TIPO  \
# 0        105001000001           6          2019         P  Principal
# 1        105001000027           6          2019         A   Adscrita
# 2        105001000043           6          2019         P  Principal
# 3        105001000078           6          2019         A   Adscrita
# 4        105001000094           6          2019
# ...               ...         ...           ...       ...        ...
# 53488    499773000322           6          2019         A   Adscrita
# 53489    499773000683           6          2019         A   Adscrita
# 53490    294001001314           6          2019         A   Adscrita
# 53491    294001001322           6          2019         A   Adscrita
# 53492    294001001331           6          2019         A   Adscrita
#
#       SEDE_CANTIDAD_ADSCRITA SEDE_CODIGO_PRINCIPAL SEDE_CANTIDAD_PLANTA_FISICA
# 0                          0
# ...

# %%
#SEDE_PLANTAS['ï»¿SEDE_CODIGO'].nunique()
#df_suffix = pd.merge(SEDE_PLANTAS, SEDE_PRINCIPAL, left_on='ï»¿SEDE_CODIGO',right_on='ï»¿SEDE_CODIGO',how='outer',suffixes=('_left','_right'))
#df_suffix
SEDE_CARATULA['MUNI']
# Out:
# 0             Sucre
# 1             Sucre
# 2             Sucre
# 3             Sucre
# 4             Sucre
#             ...
# 59047       Soledad
# 59048    Valledupar
# 59049     Caparrapí
# 59050     Caparrapí
# 59051     Caparrapí
# Name: MUNI, Length: 59052, dtype: object

# %%
SEDE_CARATULA_P=SEDE_CARATULA[['ï»¿SEDE_CODIGO','ESTADO_ID','NOVEDAD_NOMBRE','SEDE_NOMBRE','ES_SISTEMA_ETNOEDUCATIVO',
                               'CODIGOINTERNOMUNI','MUNI','AREA_NOMBRE','SECTOR_NOMBRE']]
SEDE_CARATULA.columns
SEDE_CARATULA_P
#df_suffix = pd.merge(SEDE_CARATULA_P, SEDE_ADSCRITA_P, left_on='ï»¿SEDE_CODIGO',right_on='SEDEADSC_CODIGO',how='outer',suffixes=('_left','_right'))
#df_suffix
# Out:
#        ï»¿SEDE_CODIGO  ESTADO_ID NOVEDAD_NOMBRE  \
# 0        170771000030          5          Rinde
# 1        170771000056          5          Rinde
# 2        170771000081          5          Rinde
# 3        170771000706          5          Rinde
# 4        170771000820          5          Rinde
# ...               ...        ...            ...
# 59047    308758800533          5          Rinde
# 59048    220001800353          5          Rinde
# 59049    225148000681          0       Inactiva
# 59050    225518000685          0       Inactiva
# 59051    225518000669          0       Inactiva
#
#                                              SEDE_NOMBRE  \
# 0      INSTITUCION EDUCATIVA NUESTRA SEEÑORA DE LAS M...
# 1                             CENTRO EDUCATIVO SANTANDER
# 2                           CENTRO EDUCATIVO SANTA LUCIA
# 3                              CENTRO EDUCATIVO SAN JOSE
# 4                            CENTRO EDUCATIVO 7 DE MARZO
# ...

# %%
SEDE_PRINCIPAL[SEDE_PRINCIPAL['ï»¿SEDE_CODIGO'] == 205670000720]
# Out:
# Empty DataFrame
# Columns: [ï»¿SEDE_CODIGO, PERIODO_ID, PERIODO_ANIO, SEDEPRINC_CODIGO, SEDEPRINC_NOMBRE, SEDEPRINC_DIRECCION, ID_CLASIFICACION_MUNICIPIO, CODIGOINTERNODEPTO, DEPTO, CODIGOINTERNOMUNI, MUNI, AREA_ID, AREA_CODIGO, AREA_NOMBRE, SEDEPRINC_TIPO, TIPOPRINCIPAL]
# Index: []

# %%
GRUPOS_FLEX.tail()
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  JORNADA_ID  JORNADA_CODIGO  \
# 31348    205036000075           6          2019           2               2
# 31349    247460000217           6          2019           2               2
# 31350    247460000225           6          2019           2               2
# 31351    247555027864           6          2019           2               2
# 31352    294001000695           6          2019           6               6
#
#       JORNADA_NOMBRE  MODELOEDUC_ID  MODELOEDUC_CODIGO MODELOEDUC_NOMBRE  \
# 31348         Mañana              4                  2     Escuela nueva
# 31349         Mañana              4                  2     Escuela nueva
# 31350         Mañana              4                  2     Escuela nueva
# 31351         Mañana              4                  2     Escuela nueva
# 31352          Única             17                 18       Media Rural
#
# ...

# %%
df_merge_col = pd.merge(GRUPOS_FLEX, SEDE_CARATULA_P[['ï»¿SEDE_CODIGO','MUNI']], on='ï»¿SEDE_CODIGO')
df_merge_col['MUNI'].unique()
# Out:
# array(['Sopetrán', 'Granada', 'San Roque', 'Bello',
#        'San Pedro de los Milagros', 'Barbosa', 'Rionegro', 'Urrao',
#        'Argelia', 'San Juan de Rioseco', 'Caramanta', 'Jerusalén', 'Tona',
#        'Sabana de Torres', 'Apulo', 'Giraldo', 'Calima', 'Roldanillo',
#        'Ituango', 'El Carmen de Viboral', 'Santa Rosa de Osos',
#        'Carmen de Carupa', 'Sucre', 'Barranquilla',
#        'Santa Helena del Opón', 'Gámbita', 'Puente Nacional',
#        'Sitionuevo', 'Medellín', 'Jamundí', 'El Piñón', 'Bogotá, D.C.',
#        'Fredonia', 'Murindó', 'Sevilla', 'San Luis', 'Trujillo',
#        'Remedios', 'Valparaíso', 'Tarazá', 'Fundación', 'Macaravita',
#        'Puebloviejo', 'Santo Domingo', 'Donmatías', 'Puerto Salgar',
#        'Quetame', 'Turbo', 'Hato', 'Ciudad Bolívar', 'Suaita', 'Florián',
#        'Caucasia', 'Betania', 'Montebello', 'Zaragoza', 'Gómez Plata',
#        'Arboletes', 'Yondó', 'Segovia', 'Sonsón', 'Valdivia', 'Caracolí',
# ...

# %%
GRUPOS_FLEX[GRUPOS_FLEX['MODELOEDUC_NOMBRE'] == "Ser humano"]
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  JORNADA_ID  JORNADA_CODIGO  \
# 8684     305001026084           6          2019           2               2
# 30810    347001007700           6          2019           2               2
#
#       JORNADA_NOMBRE  MODELOEDUC_ID  MODELOEDUC_CODIGO MODELOEDUC_NOMBRE  \
# 8684          Mañana             65                 26        Ser humano
# 30810         Mañana             65                 26        Ser humano
#
#        NIVELENSE_ID  NIVELENSE_CODIGO NIVELENSE_NOMBRE  JOREPM_CANTIDAD_GRUPO
# 8684              2                 2  Básica primaria                      2
# 30810             2                 2  Básica primaria                      5

# %%
SEDE_MATRICULA.head()
# Out:
#    ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  JORNADA_ID  JORNADA_CODIGO  \
# 0    205107000853           6          2019           6               6
# 1    205093000014           6          2019           2               2
# 2    205093000014           6          2019           2               2
# 3    205093000014           6          2019           2               2
# 4    205093000014           6          2019           2               2
#
#   JORNADA_NOMBRE  NIVELENSE_ID  NIVELENSE_CODIGO   NIVELENSE_NOMBRE  \
# 0          Única             2                 2    Básica primaria
# 1         Mañana             1                 1         Preescolar
# 2         Mañana             2                 2    Básica primaria
# 3         Mañana             3                 3  Básica secundaria
# 4         Mañana             4                 4              Media
#
#    TIPOMATRI_ID  TIPOMATRI_CODIGO  TIPOMATRI_NOMBRE  JORMAT_CANTIDAD_ALUMNO
# ...

# %%
df_merge_col = pd.merge(SEDE_MATRICULA, SEDE_CARATULA_P[['ï»¿SEDE_CODIGO','CODIGOINTERNOMUNI','MUNI']], on='ï»¿SEDE_CODIGO')
df_merge_col
# Out:
#         ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  JORNADA_ID  JORNADA_CODIGO  \
# 0         205107000853           6          2019           6               6
# 1         205093000014           6          2019           2               2
# 2         205093000014           6          2019           2               2
# 3         205093000014           6          2019           2               2
# 4         205093000014           6          2019           2               2
# ...                ...         ...           ...         ...             ...
# 130699    294001001390           6          2019           2               2
# 130700    294001000814           6          2019           2               2
# 130701    294001000814           6          2019           2               2
# 130702    294001000032           6          2019           2               2
# 130703    294001000032           6          2019           2               2
#
# ...

# %%
df_merge_col[df_merge_col['JORNADA_CODIGO'] == 2].groupby('MUNI')[['JORMAT_CANTIDAD_ALUMNO']].sum()
# Out:
#                JORMAT_CANTIDAD_ALUMNO
# MUNI
# Abejorral                        2286
# Abriaquí                          333
# Acacías                         12572
# Acandí                           1229
# Acevedo                          4988
# ...                               ...
# Zona Bananera                   15889
# Ábrego                           5486
# Íquira                           1451
# Úmbita                            954
# Útica                             514
#
# [1007 rows x 1 columns]

# %%
df_merge_col[df_merge_col['JORNADA_CODIGO'] == 1].groupby('MUNI')[['JORMAT_CANTIDAD_ALUMNO']].sum()
# Out:
#                  JORMAT_CANTIDAD_ALUMNO
# MUNI
# Acacías                            2563
# Agua de Dios                         36
# Aguachica                           278
# Aguazul                             661
# Agustín Codazzi                     136
# ...                                 ...
# Yumbo                              3800
# Zapatoca                            272
# Zaragoza                            192
# Zarzal                              407
# Zipaquirá                          4103
#
# [273 rows x 1 columns]

# %%
df=df_merge_col.pivot_table(index='MUNI',columns='JORNADA_NOMBRE',aggfunc=sum, values='JORMAT_CANTIDAD_ALUMNO')
df
# Out:
# JORNADA_NOMBRE  Completa  Fin de Semana   Mañana  Nocturna   Tarde   Única
# MUNI
# Abejorral            NaN           39.0   2286.0       NaN     NaN   977.0
# Abriaquí             NaN            NaN    333.0       NaN     NaN    19.0
# Acacías           2563.0          424.0  12572.0     158.0  3385.0   297.0
# Acandí               NaN            NaN   1229.0     208.0   181.0  1962.0
# Acevedo              NaN          190.0   4988.0     376.0     NaN  2179.0
# ...                  ...            ...      ...       ...     ...     ...
# Zona Bananera        NaN           40.0  15889.0    2388.0  4535.0   497.0
# Ábrego               NaN          753.0   5486.0     487.0  1279.0   203.0
# Íquira               NaN            NaN   1451.0      87.0     NaN   787.0
# Úmbita               NaN            NaN    954.0       NaN     NaN   297.0
# Útica                NaN           35.0    514.0       NaN     NaN    86.0
#
# [1036 rows x 6 columns]

# %%
df.fillna(0,inplace=True)
#df.columns = df.columns.droplevel()
df.columns.name = None
df.reset_index(inplace=True)
df
# Out:
#                MUNI  Completa  Fin de Semana   Mañana  Nocturna   Tarde  \
# 0         Abejorral       0.0           39.0   2286.0       0.0     0.0
# 1          Abriaquí       0.0            0.0    333.0       0.0     0.0
# 2           Acacías    2563.0          424.0  12572.0     158.0  3385.0
# 3            Acandí       0.0            0.0   1229.0     208.0   181.0
# 4           Acevedo       0.0          190.0   4988.0     376.0     0.0
# ...             ...       ...            ...      ...       ...     ...
# 1031  Zona Bananera       0.0           40.0  15889.0    2388.0  4535.0
# 1032         Ábrego       0.0          753.0   5486.0     487.0  1279.0
# 1033         Íquira       0.0            0.0   1451.0      87.0     0.0
# 1034         Úmbita       0.0            0.0    954.0       0.0     0.0
# 1035          Útica       0.0           35.0    514.0       0.0     0.0
#
#        Única
# 0      977.0
# 1       19.0
# 2      297.0
# 3     1962.0
# 4     2179.0
# ...      ...
# ...

# %%
df.rename(columns={'Completa':'SED_01',
                   'Mañana':'SED_02',
                   'Tarde':'SED_03',
                   'Nocturna':'SED_04',
                   'Fin de Semana':'SED_05',
                   'Única':'SED_06'},
                   inplace=True)
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0
# ...             ...     ...     ...      ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0
#
# [1036 rows x 7 columns]

# %%
SED_07=df_merge_col.groupby('MUNI')[['JORNADA_NOMBRE']].nunique()
SED_07.fillna(0,inplace=True)
SED_07.columns.name = None
SED_07.reset_index(inplace=True)

SED_07
df = pd.merge(df, SED_07, on='MUNI')
df.rename(columns={'JORNADA_NOMBRE':'SED_07'},
                   inplace=True)
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# [1036 rows x 8 columns]

# %%
SED_08=df_merge_col.groupby('MUNI')[['JORMAT_CANTIDAD_ALUMNO']].sum()
SED_08.fillna(0,inplace=True)
SED_08.columns.name = None
SED_08.reset_index(inplace=True)

SED_08
df = pd.merge(df, SED_08, on='MUNI')
df.rename(columns={'JORMAT_CANTIDAD_ALUMNO':'SED_08'},
                   inplace=True)
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
#       SED_08
# 0       3302
# 1        352
# ...

# %%
SED_09=df_merge_col.pivot_table(index='MUNI',columns='NIVELENSE_CODIGO',aggfunc=sum, values='JORMAT_CANTIDAD_ALUMNO')
SED_09
# Out:
# NIVELENSE_CODIGO       1       2       3       4       5
# MUNI
# Abejorral          221.0  1433.0  1178.0   431.0    39.0
# Abriaquí            30.0   151.0   125.0    46.0     NaN
# Acacías           2013.0  7800.0  6011.0  2162.0  1413.0
# Acandí             305.0  1767.0   984.0   261.0   263.0
# Acevedo            571.0  3742.0  2315.0   539.0   566.0
# ...                  ...     ...     ...     ...     ...
# Zona Bananera     2510.0  9836.0  6680.0  1895.0  2428.0
# Ábrego             553.0  3920.0  2019.0   476.0  1240.0
# Íquira             172.0  1141.0   736.0   189.0    87.0
# Úmbita              89.0   540.0   398.0   224.0     NaN
# Útica               37.0   239.0   238.0    86.0    35.0
#
# [1036 rows x 5 columns]

# %%
SED_09.fillna(0,inplace=True)
SED_09.columns.name = None
SED_09.reset_index(inplace=True)
SED_09.rename(columns={1:'SED_09',
                       2:'SED_10',
                       3:'SED_11',
                       4:'SED_12',
                       5:'SED_13'},
                   inplace=True)
SED_09
# Out:
#                MUNI  SED_09  SED_10  SED_11  SED_12  SED_13
# 0         Abejorral   221.0  1433.0  1178.0   431.0    39.0
# 1          Abriaquí    30.0   151.0   125.0    46.0     0.0
# 2           Acacías  2013.0  7800.0  6011.0  2162.0  1413.0
# 3            Acandí   305.0  1767.0   984.0   261.0   263.0
# 4           Acevedo   571.0  3742.0  2315.0   539.0   566.0
# ...             ...     ...     ...     ...     ...     ...
# 1031  Zona Bananera  2510.0  9836.0  6680.0  1895.0  2428.0
# 1032         Ábrego   553.0  3920.0  2019.0   476.0  1240.0
# 1033         Íquira   172.0  1141.0   736.0   189.0    87.0
# 1034         Úmbita    89.0   540.0   398.0   224.0     0.0
# 1035          Útica    37.0   239.0   238.0    86.0    35.0
#
# [1036 rows x 6 columns]

# %%
df = pd.merge(df, SED_09, on='MUNI')
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
df_merge_col['TIPOMATRI_NOMBRE'].unique()
# Out:
# array(['Matrícula propia', 'Matrícula contratada'], dtype=object)

# %%
SED_14=df_merge_col[df_merge_col['TIPOMATRI_NOMBRE'] == "Matrícula contratada"].groupby('MUNI')[['JORMAT_CANTIDAD_ALUMNO']].sum()
SED_14.fillna(0,inplace=True)
SED_14.columns.name = None
SED_14.reset_index(inplace=True)

df = pd.merge(df, SED_14,how='left', on='MUNI')
df.rename(columns={'JORMAT_CANTIDAD_ALUMNO':'SED_14'},
                   inplace=True)
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
SED_15=df_merge_col[df_merge_col['TIPOMATRI_NOMBRE'] == "Matrícula propia"].groupby('MUNI')[['JORMAT_CANTIDAD_ALUMNO']].sum()
SED_15.fillna(0,inplace=True)
SED_15.columns.name = None
SED_15.reset_index(inplace=True)

df = pd.merge(df, SED_15,how='left',on='MUNI')
df.rename(columns={'JORMAT_CANTIDAD_ALUMNO':'SED_15'},
                   inplace=True)
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
df['SED_14'] = (df['SED_14'] / df['SED_08'])
df['SED_15'] = (df['SED_15'] / df['SED_08'])
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
TIC_CANT
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  EQUIPOCOM_ID  \
# 0        311001004196           6          2019             1
# 1        311001004196           6          2019             2
# 2        299572000325           6          2019             2
# 3        308078000770           6          2019             1
# 4        308078000770           6          2019             2
# ...               ...         ...           ...           ...
# 83745    125473000137           6          2019             3
# 83746    391001000992           6          2019             2
# 83747    391001000992           6          2019             1
# 83748    311001109788           6          2019             1
# 83749    311001109788           6          2019             2
#
#        EQUIPOCOM_CODIGO            EQUIPOCOM_NOMBRE  SEDECOM_CANTIDAD  \
# 0                     1  Computadores de escritorio                43
# 1                     2     Computadores portátiles                10
# ...

# %%
TIC_CANT_merge = pd.merge(TIC_CANT, SEDE_CARATULA_P[['ï»¿SEDE_CODIGO','CODIGOINTERNOMUNI','MUNI']], on='ï»¿SEDE_CODIGO')
TIC_CANT_merge
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  EQUIPOCOM_ID  \
# 0        311001004196           6          2019             1
# 1        311001004196           6          2019             2
# 2        299572000325           6          2019             2
# 3        308078000770           6          2019             1
# 4        308078000770           6          2019             2
# ...               ...         ...           ...           ...
# 83745    125473000137           6          2019             3
# 83746    391001000992           6          2019             2
# 83747    391001000992           6          2019             1
# 83748    311001109788           6          2019             1
# 83749    311001109788           6          2019             2
#
#        EQUIPOCOM_CODIGO            EQUIPOCOM_NOMBRE  SEDECOM_CANTIDAD  \
# 0                     1  Computadores de escritorio                43
# 1                     2     Computadores portátiles                10
# ...

# %%
TIC_CANT_merge['EQUIPOCOM_NOMBRE'].unique()
# Out:
# array(['Computadores de escritorio', 'Computadores portátiles',
#        'Tabletas'], dtype=object)

# %%
TIC_CANT_merge_1 = TIC_CANT_merge[(TIC_CANT_merge['EQUIPOCOM_NOMBRE'] == 'Computadores de escritorio') | 
               (TIC_CANT_merge['EQUIPOCOM_NOMBRE'] == 'Computadores portátiles')]
TIC_CANT_merge_1
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  EQUIPOCOM_ID  \
# 0        311001004196           6          2019             1
# 1        311001004196           6          2019             2
# 2        299572000325           6          2019             2
# 3        308078000770           6          2019             1
# 4        308078000770           6          2019             2
# ...               ...         ...           ...           ...
# 83744    125473000137           6          2019             2
# 83746    391001000992           6          2019             2
# 83747    391001000992           6          2019             1
# 83748    311001109788           6          2019             1
# 83749    311001109788           6          2019             2
#
#        EQUIPOCOM_CODIGO            EQUIPOCOM_NOMBRE  SEDECOM_CANTIDAD  \
# 0                     1  Computadores de escritorio                43
# 1                     2     Computadores portátiles                10
# ...

# %%
TIC_CANT_merge_2 = TIC_CANT_merge[(TIC_CANT_merge['EQUIPOCOM_NOMBRE'] == 'Tabletas')]
TIC_CANT_merge_2
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  EQUIPOCOM_ID  \
# 5        299773003021           6          2019             3
# 9        125295000012           6          2019             3
# 14       205400000043           6          2019             3
# 19       168276002862           6          2019             3
# 22       125899000380           6          2019             3
# ...               ...         ...           ...           ...
# 83738    294001001047           6          2019             3
# 83739    294001001349           6          2019             3
# 83740    294001000831           6          2019             3
# 83742    294001001012           6          2019             3
# 83745    125473000137           6          2019             3
#
#        EQUIPOCOM_CODIGO EQUIPOCOM_NOMBRE  SEDECOM_CANTIDAD  \
# 5                     3         Tabletas                15
# 9                     3         Tabletas                30
# ...

# %%
df_merge_col_1 = df_merge_col.groupby(['ï»¿SEDE_CODIGO','MUNI'])[['JORMAT_CANTIDAD_ALUMNO']].sum()
#SED_15.fillna(0,inplace=True)
df_merge_col_1.columns.name = None
df_merge_col_1.reset_index(inplace=True)
df_merge_col_1
# Out:
#        ï»¿SEDE_CODIGO      MUNI  JORMAT_CANTIDAD_ALUMNO
# 0        105001000001  Medellín                    1068
# 1        105001000027  Medellín                     367
# 2        105001000043  Medellín                    1340
# 3        105001000078  Medellín                     528
# 4        105001000094  Medellín                     354
# ...               ...       ...                     ...
# 53522    499760001109  Cumaribo                     386
# 53523    499760001125  Cumaribo                     131
# 53524    499773000187  Cumaribo                      47
# 53525    499773000322  Cumaribo                      22
# 53526    499773000683  Cumaribo                      29
#
# [53527 rows x 3 columns]

# %%
TIC_CANT_merge_1_1 = TIC_CANT_merge_1.groupby(['ï»¿SEDE_CODIGO','MUNI'])[['SEDECOM_CANTIDAD']].sum()
TIC_CANT_merge_1_1
# Out:
#                          SEDECOM_CANTIDAD
# ï»¿SEDE_CODIGO MUNI
# 105001000001   Medellín                82
# 105001000027   Medellín                49
# 105001000043   Medellín                61
# 105001000078   Medellín                61
# 105001000094   Medellín                20
# ...                                   ...
# 499001001919   Cumaribo                60
# 499760000803   Cumaribo                 0
# 499760000994   Cumaribo                 5
# 499760001109   Cumaribo                12
# 499760001125   Cumaribo                 6
#
# [43160 rows x 1 columns]

# %%
TIC_CANT_merge_1_1 = pd.merge(TIC_CANT_merge_1_1, df_merge_col_1, on='ï»¿SEDE_CODIGO')
TIC_CANT_merge_1_1
#TIC_CANT_merge_1_1['TIC_01']= TIC_CANT_merge_1_1['SEDECOM_CANTIDAD'] / TIC_CANT_merge_1_1['JORMAT_CANTIDAD_ALUMNO']
# Out:
#        ï»¿SEDE_CODIGO  SEDECOM_CANTIDAD      MUNI  JORMAT_CANTIDAD_ALUMNO
# 0        105001000001                82  Medellín                    1068
# 1        105001000027                49  Medellín                     367
# 2        105001000043                61  Medellín                    1340
# 3        105001000078                61  Medellín                     528
# 4        105001000094                20  Medellín                     354
# ...               ...               ...       ...                     ...
# 43155    499001001919                60  Cumaribo                     414
# 43156    499760000803                 0  Cumaribo                      42
# 43157    499760000994                 5  Cumaribo                     177
# 43158    499760001109                12  Cumaribo                     386
# 43159    499760001125                 6  Cumaribo                     131
#
# [43160 rows x 4 columns]

# %%
TIC_CANT_merge_1_1['TIC_01']= (TIC_CANT_merge_1_1['SEDECOM_CANTIDAD']) / (TIC_CANT_merge_1_1['JORMAT_CANTIDAD_ALUMNO'])
TIC_CANT_merge_1_1
# Out:
#        ï»¿SEDE_CODIGO  SEDECOM_CANTIDAD      MUNI  JORMAT_CANTIDAD_ALUMNO  \
# 0        105001000001                82  Medellín                    1068
# 1        105001000027                49  Medellín                     367
# 2        105001000043                61  Medellín                    1340
# 3        105001000078                61  Medellín                     528
# 4        105001000094                20  Medellín                     354
# ...               ...               ...       ...                     ...
# 43155    499001001919                60  Cumaribo                     414
# 43156    499760000803                 0  Cumaribo                      42
# 43157    499760000994                 5  Cumaribo                     177
# 43158    499760001109                12  Cumaribo                     386
# 43159    499760001125                 6  Cumaribo                     131
#
#          TIC_01
# 0      0.076779
# 1      0.133515
# 2      0.045522
# ...

# %%
TIC_01 = TIC_CANT_merge_1_1.groupby('MUNI')[['TIC_01']].mean()
TIC_01.columns.name = None
TIC_01.reset_index(inplace=True)
TIC_01
# Out:
#                MUNI    TIC_01
# 0         Abejorral  0.302776
# 1          Abriaquí  0.494417
# 2           Acacías  0.152037
# 3            Acandí  0.193688
# 4           Acevedo  0.276252
# ...             ...       ...
# 1027  Zona Bananera  0.047816
# 1028         Ábrego  0.416384
# 1029         Íquira  0.619244
# 1030         Úmbita  0.378415
# 1031          Útica  0.897946
#
# [1032 rows x 2 columns]

# %%
df = pd.merge(df, TIC_01, how='left',on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
TIC_CANT_merge_2_1 = TIC_CANT_merge_2.groupby(['ï»¿SEDE_CODIGO','MUNI'])[['SEDECOM_CANTIDAD']].sum()
TIC_CANT_merge_2_1
# Out:
#                              SEDECOM_CANTIDAD
# ï»¿SEDE_CODIGO MUNI
# 105001000001   Medellín                     0
# 105001000043   Medellín                    19
# 105001000078   Medellín                     9
# 105001000108   Medellín                     0
# 105001000132   Medellín                     0
# ...                                       ...
# 499001001102   Cumaribo                    13
# 499001001170   La Primavera                19
# 499001001919   Cumaribo                    60
# 499760000994   Cumaribo                     7
# 499760001125   Cumaribo                    15
#
# [19116 rows x 1 columns]

# %%
TIC_CANT_merge_2_1 = pd.merge(TIC_CANT_merge_2_1, df_merge_col_1, on='ï»¿SEDE_CODIGO')
TIC_CANT_merge_2_1
# Out:
#        ï»¿SEDE_CODIGO  SEDECOM_CANTIDAD          MUNI  JORMAT_CANTIDAD_ALUMNO
# 0        105001000001                 0      Medellín                    1068
# 1        105001000043                19      Medellín                    1340
# 2        105001000078                 9      Medellín                     528
# 3        105001000108                 0      Medellín                    2033
# 4        105001000132                 0      Medellín                     921
# ...               ...               ...           ...                     ...
# 19111    499001001102                13      Cumaribo                      57
# 19112    499001001170                19  La Primavera                     192
# 19113    499001001919                60      Cumaribo                     414
# 19114    499760000994                 7      Cumaribo                     177
# 19115    499760001125                15      Cumaribo                     131
#
# [19116 rows x 4 columns]

# %%
TIC_CANT_merge_2_1['TIC_02']= (TIC_CANT_merge_2_1['SEDECOM_CANTIDAD']) / (TIC_CANT_merge_2_1['JORMAT_CANTIDAD_ALUMNO'])
TIC_CANT_merge_2_1
# Out:
#        ï»¿SEDE_CODIGO  SEDECOM_CANTIDAD          MUNI  JORMAT_CANTIDAD_ALUMNO  \
# 0        105001000001                 0      Medellín                    1068
# 1        105001000043                19      Medellín                    1340
# 2        105001000078                 9      Medellín                     528
# 3        105001000108                 0      Medellín                    2033
# 4        105001000132                 0      Medellín                     921
# ...               ...               ...           ...                     ...
# 19111    499001001102                13      Cumaribo                      57
# 19112    499001001170                19  La Primavera                     192
# 19113    499001001919                60      Cumaribo                     414
# 19114    499760000994                 7      Cumaribo                     177
# 19115    499760001125                15      Cumaribo                     131
#
#          TIC_02
# ...

# %%
TIC_02 = TIC_CANT_merge_2_1.groupby('MUNI')[['TIC_02']].mean()
TIC_02.columns.name = None
TIC_02.reset_index(inplace=True)
TIC_02
# Out:
#                MUNI    TIC_02
# 0         Abejorral  0.349016
# 1          Abriaquí  0.336640
# 2           Acacías  0.483520
# 3            Acandí  0.380064
# 4           Acevedo  0.505187
# ...             ...       ...
# 1004  Zona Bananera  0.175527
# 1005         Ábrego  0.143914
# 1006         Íquira  0.668583
# 1007         Úmbita  0.742320
# 1008          Útica  1.357224
#
# [1009 rows x 2 columns]

# %%
df = pd.merge(df, TIC_02,how='left', on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
import missingno as msno 
TIC_SERVICIOS

msno.matrix(TIC_SERVICIOS)

# %%
TIC_SERVICIOS_merge = pd.merge(TIC_SERVICIOS, SEDE_CARATULA_P[['ï»¿SEDE_CODIGO','CODIGOINTERNOMUNI','MUNI']], on='ï»¿SEDE_CODIGO')
TIC_SERVICIOS_merge
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  SEDETE_ELECTRICIDAD  \
# 0        308758003315           6          2019                    1
# 1        308001075769           6          2019                    1
# 2        268500000174           6          2019                    1
# 3        205145000522           6          2019                    1
# 4        325307001507           6          2019                    1
# ...               ...         ...           ...                  ...
# 53522    294001000695           6          2019                    1
# 53523    294001001331           6          2019                    0
# 53524    294001001047           6          2019                    1
# 53525    311001109788           6          2019                    1
# 53526    294001000482           6          2019                    1
#
#       TIENEELECTRICIDAD  SEDETE_TELEVISION TIENETELEVISION  SEDETE_LINEA_TEL  \
# ...

# %%
#TIC_03 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_ELECTRICIDAD'] == "1"].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
#TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_ELECTRICIDAD'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_SERVICIOS_Total = TIC_SERVICIOS_merge.groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
#TIC_SERVICIOS_Total.fillna(0,inplace=True)
TIC_SERVICIOS_Total.columns.name = None
TIC_SERVICIOS_Total.reset_index(inplace=True)
TIC_SERVICIOS_Total.rename(columns={'ï»¿SEDE_CODIGO':'total'},
                   inplace=True)
TIC_SERVICIOS_Total
# Out:
#                MUNI  total
# 0         Abejorral     67
# 1          Abriaquí     10
# 2           Acacías     67
# 3            Acandí     28
# 4           Acevedo     88
# ...             ...    ...
# 1031  Zona Bananera     82
# 1032         Ábrego    130
# 1033         Íquira     31
# 1034         Úmbita     24
# 1035          Útica     14
#
# [1036 rows x 2 columns]

# %%
TIC_03_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_ELECTRICIDAD'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_03_1.fillna(0,inplace=True)
TIC_03_1.columns.name = None
TIC_03_1.reset_index(inplace=True)
TIC_03_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_03_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_03_1,how='left', on='MUNI')

TIC_03_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_ELECTRICIDAD'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()

TIC_03_0.columns.name = None
TIC_03_0.reset_index(inplace=True)
TIC_03_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_03_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_03_0,how='left', on='MUNI')
#TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0
# 0         Abejorral     67      59.0       8.0
# 1          Abriaquí     10      10.0       0.0
# 2           Acacías     67      66.0       1.0
# 3            Acandí     28      12.0      16.0
# 4           Acevedo     88      86.0       2.0
# ...             ...    ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0
# 1032         Ábrego    130     111.0      19.0
# 1033         Íquira     31      31.0       0.0
# 1034         Úmbita     24      24.0       0.0
# 1035          Útica     14      12.0       2.0
#
# [1036 rows x 4 columns]

# %%
TIC_04_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_TELEVISION'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_04_1.fillna(0,inplace=True)
TIC_04_1.columns.name = None
TIC_04_1.reset_index(inplace=True)
TIC_04_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_04_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_04_1,how='left', on='MUNI')

TIC_04_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_TELEVISION'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()

TIC_04_0.columns.name = None
TIC_04_0.reset_index(inplace=True)
TIC_04_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_04_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_04_0,how='left', on='MUNI')
TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0
# 0         Abejorral     67      59.0       8.0      24.0      43.0
# 1          Abriaquí     10      10.0       0.0       4.0       6.0
# 2           Acacías     67      66.0       1.0      41.0      26.0
# 3            Acandí     28      12.0      16.0       9.0      19.0
# 4           Acevedo     88      86.0       2.0      18.0      70.0
# ...             ...    ...       ...       ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0      49.0      33.0
# 1032         Ábrego    130     111.0      19.0      35.0      95.0
# 1033         Íquira     31      31.0       0.0      23.0       8.0
# 1034         Úmbita     24      24.0       0.0      17.0       7.0
# 1035          Útica     14      12.0       2.0       0.0      14.0
#
# [1036 rows x 6 columns]

# %%
TIC_05_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_LINEA_TEL'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_05_1.fillna(0,inplace=True)
TIC_05_1.columns.name = None
TIC_05_1.reset_index(inplace=True)
TIC_05_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_05_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_05_1,how='left', on='MUNI')

TIC_05_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_LINEA_TEL'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()

TIC_05_0.columns.name = None
TIC_05_0.reset_index(inplace=True)
TIC_05_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_05_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_05_0,how='left', on='MUNI')
TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0  TIC_05_1  \
# 0         Abejorral     67      59.0       8.0      24.0      43.0       5.0
# 1          Abriaquí     10      10.0       0.0       4.0       6.0       2.0
# 2           Acacías     67      66.0       1.0      41.0      26.0      25.0
# 3            Acandí     28      12.0      16.0       9.0      19.0       2.0
# 4           Acevedo     88      86.0       2.0      18.0      70.0       2.0
# ...             ...    ...       ...       ...       ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0      49.0      33.0       5.0
# 1032         Ábrego    130     111.0      19.0      35.0      95.0       1.0
# 1033         Íquira     31      31.0       0.0      23.0       8.0       3.0
# 1034         Úmbita     24      24.0       0.0      17.0       7.0       3.0
# 1035          Útica     14      12.0       2.0       0.0      14.0       0.0
#
#       TIC_05_0
# 0         62.0
# ...

# %%
TIC_06_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_RADIO'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_06_1.columns.name = None
TIC_06_1.reset_index(inplace=True)
TIC_06_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_06_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_06_1,how='left', on='MUNI')

TIC_06_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_RADIO'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_06_0.columns.name = None
TIC_06_0.reset_index(inplace=True)
TIC_06_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_06_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_06_0,how='left', on='MUNI')
TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0  TIC_05_1  \
# 0         Abejorral     67      59.0       8.0      24.0      43.0       5.0
# 1          Abriaquí     10      10.0       0.0       4.0       6.0       2.0
# 2           Acacías     67      66.0       1.0      41.0      26.0      25.0
# 3            Acandí     28      12.0      16.0       9.0      19.0       2.0
# 4           Acevedo     88      86.0       2.0      18.0      70.0       2.0
# ...             ...    ...       ...       ...       ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0      49.0      33.0       5.0
# 1032         Ábrego    130     111.0      19.0      35.0      95.0       1.0
# 1033         Íquira     31      31.0       0.0      23.0       8.0       3.0
# 1034         Úmbita     24      24.0       0.0      17.0       7.0       3.0
# 1035          Útica     14      12.0       2.0       0.0      14.0       0.0
#
#       TIC_05_0  TIC_06_1  TIC_06_0
# ...

# %%
TIC_07_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_LAN'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_07_1.columns.name = None
TIC_07_1.reset_index(inplace=True)
TIC_07_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_07_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_07_1,how='left', on='MUNI')

TIC_07_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_LAN'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_07_0.columns.name = None
TIC_07_0.reset_index(inplace=True)
TIC_07_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_07_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_07_0,how='left', on='MUNI')
TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0  TIC_05_1  \
# 0         Abejorral     67      59.0       8.0      24.0      43.0       5.0
# 1          Abriaquí     10      10.0       0.0       4.0       6.0       2.0
# 2           Acacías     67      66.0       1.0      41.0      26.0      25.0
# 3            Acandí     28      12.0      16.0       9.0      19.0       2.0
# 4           Acevedo     88      86.0       2.0      18.0      70.0       2.0
# ...             ...    ...       ...       ...       ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0      49.0      33.0       5.0
# 1032         Ábrego    130     111.0      19.0      35.0      95.0       1.0
# 1033         Íquira     31      31.0       0.0      23.0       8.0       3.0
# 1034         Úmbita     24      24.0       0.0      17.0       7.0       3.0
# 1035          Útica     14      12.0       2.0       0.0      14.0       0.0
#
# ...

# %%
TIC_08_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_INTERNET'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_08_1.columns.name = None
TIC_08_1.reset_index(inplace=True)
TIC_08_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_08_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_08_1,how='left', on='MUNI')

TIC_08_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_INTERNET'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_08_0.columns.name = None
TIC_08_0.reset_index(inplace=True)
TIC_08_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_08_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_08_0,how='left', on='MUNI')
TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0  TIC_05_1  \
# 0         Abejorral     67      59.0       8.0      24.0      43.0       5.0
# 1          Abriaquí     10      10.0       0.0       4.0       6.0       2.0
# 2           Acacías     67      66.0       1.0      41.0      26.0      25.0
# 3            Acandí     28      12.0      16.0       9.0      19.0       2.0
# 4           Acevedo     88      86.0       2.0      18.0      70.0       2.0
# ...             ...    ...       ...       ...       ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0      49.0      33.0       5.0
# 1032         Ábrego    130     111.0      19.0      35.0      95.0       1.0
# 1033         Íquira     31      31.0       0.0      23.0       8.0       3.0
# 1034         Úmbita     24      24.0       0.0      17.0       7.0       3.0
# 1035          Útica     14      12.0       2.0       0.0      14.0       0.0
#
# ...

# %%
TIC_10_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_EQUIPO_COMPUTO'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_10_1.columns.name = None
TIC_10_1.reset_index(inplace=True)
TIC_10_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_10_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_10_1,how='left', on='MUNI')

TIC_10_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_EQUIPO_COMPUTO'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_10_0.columns.name = None
TIC_10_0.reset_index(inplace=True)
TIC_10_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_10_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_10_0,how='left', on='MUNI')
TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0  TIC_05_1  \
# 0         Abejorral     67      59.0       8.0      24.0      43.0       5.0
# 1          Abriaquí     10      10.0       0.0       4.0       6.0       2.0
# 2           Acacías     67      66.0       1.0      41.0      26.0      25.0
# 3            Acandí     28      12.0      16.0       9.0      19.0       2.0
# 4           Acevedo     88      86.0       2.0      18.0      70.0       2.0
# ...             ...    ...       ...       ...       ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0      49.0      33.0       5.0
# 1032         Ábrego    130     111.0      19.0      35.0      95.0       1.0
# 1033         Íquira     31      31.0       0.0      23.0       8.0       3.0
# 1034         Úmbita     24      24.0       0.0      17.0       7.0       3.0
# 1035          Útica     14      12.0       2.0       0.0      14.0       0.0
#
# ...

# %%
TIC_11_1 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_SERVICIO_EXTERNO'] == 1].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_11_1.columns.name = None
TIC_11_1.reset_index(inplace=True)
TIC_11_1.rename(columns={'ï»¿SEDE_CODIGO':'TIC_11_1'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_11_1,how='left', on='MUNI')

TIC_11_0 = TIC_SERVICIOS_merge[TIC_SERVICIOS_merge['SEDETE_SERVICIO_EXTERNO'] == 0].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
TIC_11_0.columns.name = None
TIC_11_0.reset_index(inplace=True)
TIC_11_0.rename(columns={'ï»¿SEDE_CODIGO':'TIC_11_0'},inplace=True)
TIC_SERVICIOS_Total = pd.merge(TIC_SERVICIOS_Total, TIC_11_0,how='left', on='MUNI')
TIC_SERVICIOS_Total.fillna(0,inplace=True)

TIC_SERVICIOS_Total
# Out:
#                MUNI  total  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0  TIC_05_1  \
# 0         Abejorral     67      59.0       8.0      24.0      43.0       5.0
# 1          Abriaquí     10      10.0       0.0       4.0       6.0       2.0
# 2           Acacías     67      66.0       1.0      41.0      26.0      25.0
# 3            Acandí     28      12.0      16.0       9.0      19.0       2.0
# 4           Acevedo     88      86.0       2.0      18.0      70.0       2.0
# ...             ...    ...       ...       ...       ...       ...       ...
# 1031  Zona Bananera     82      79.0       3.0      49.0      33.0       5.0
# 1032         Ábrego    130     111.0      19.0      35.0      95.0       1.0
# 1033         Íquira     31      31.0       0.0      23.0       8.0       3.0
# 1034         Úmbita     24      24.0       0.0      17.0       7.0       3.0
# 1035          Útica     14      12.0       2.0       0.0      14.0       0.0
#
# ...

# %%
msno.matrix(TIC_SERVICIOS_Total)

# %%
TIC_SERVICIOS_Total = TIC_SERVICIOS_Total.drop(['total'], axis=1)
TIC_SERVICIOS_Total
# Out:
#                MUNI  TIC_03_1  TIC_03_0  TIC_04_1  TIC_04_0  TIC_05_1  \
# 0         Abejorral      59.0       8.0      24.0      43.0       5.0
# 1          Abriaquí      10.0       0.0       4.0       6.0       2.0
# 2           Acacías      66.0       1.0      41.0      26.0      25.0
# 3            Acandí      12.0      16.0       9.0      19.0       2.0
# 4           Acevedo      86.0       2.0      18.0      70.0       2.0
# ...             ...       ...       ...       ...       ...       ...
# 1031  Zona Bananera      79.0       3.0      49.0      33.0       5.0
# 1032         Ábrego     111.0      19.0      35.0      95.0       1.0
# 1033         Íquira      31.0       0.0      23.0       8.0       3.0
# 1034         Úmbita      24.0       0.0      17.0       7.0       3.0
# 1035          Útica      12.0       2.0       0.0      14.0       0.0
#
#       TIC_05_0  TIC_06_1  TIC_06_0  TIC_07_1  TIC_07_0  TIC_08_1  TIC_08_0  \
# ...

# %%
df = pd.merge(df, TIC_SERVICIOS_Total,how='left', on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
SEDE_PRINCIPAL.groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
# Out:
#                ï»¿SEDE_CODIGO
# MUNI
# Abejorral                  63
# Abriaquí                    9
# Acacías                    34
# Acandí                     23
# Acevedo                    76
# ...                       ...
# Zona Bananera              45
# Ábrego                    114
# Íquira                     27
# Úmbita                     20
# Útica                      13
#
# [1033 rows x 1 columns]

# %%
SEDE_CARATULA
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO  ESTADO_ID ESTADO_NOMBRE  \
# 0        170771000030           6          2019          5      Aprobado
# 1        170771000056           6          2019          5      Aprobado
# 2        170771000081           6          2019          5      Aprobado
# 3        170771000706           6          2019          5      Aprobado
# 4        170771000820           6          2019          5      Aprobado
# ...               ...         ...           ...        ...           ...
# 59047    308758800533           6          2019          5      Aprobado
# 59048    220001800353           6          2019          5      Aprobado
# 59049    225148000681           6          2019          0   Sin Digitar
# 59050    225518000685           6          2019          0   Sin Digitar
# 59051    225518000669           6          2019          0   Sin Digitar
#
#        NOVEDAD_ID  NOVEDAD_CODIGO NOVEDAD_NOMBRE SEDE_NOVEDAD_OBSERVACION  \
# ...

# %%
SED_16 = SEDE_CARATULA[SEDE_CARATULA['NOVEDAD_NOMBRE'] == "Rinde"].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
SED_16.fillna(0,inplace=True)
SED_16.columns.name = None
SED_16.reset_index(inplace=True)
SED_16.rename(columns={'ï»¿SEDE_CODIGO':'SED_16'},
                   inplace=True)
df = pd.merge(df, SED_16,how='left', on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
SEDE_CARATULA['AREA_NOMBRE'].unique()
# Out:
# array(['Urbana', 'Rural'], dtype=object)

# %%
SEDE_CARATULA_RINDE = SEDE_CARATULA[SEDE_CARATULA['NOVEDAD_NOMBRE'] == "Rinde"]

# %%
SED_17 = SEDE_CARATULA_RINDE[SEDE_CARATULA_RINDE['AREA_NOMBRE'] == "Urbana"].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
SED_17.fillna(0,inplace=True)
SED_17.columns.name = None
SED_17.reset_index(inplace=True)
SED_17.rename(columns={'ï»¿SEDE_CODIGO':'SED_17'},
                   inplace=True)
df = pd.merge(df, SED_17,how='left', on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
SED_18 = SEDE_CARATULA_RINDE[SEDE_CARATULA_RINDE['AREA_NOMBRE'] == "Rural"].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
SED_18.fillna(0,inplace=True)
SED_18.columns.name = None
SED_18.reset_index(inplace=True)
SED_18.rename(columns={'ï»¿SEDE_CODIGO':'SED_18'},
                   inplace=True)
df = pd.merge(df, SED_18,how='left', on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
df['SED_19']= df['SED_17'] / df['SED_16']
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
SED_20 = SEDE_CARATULA_RINDE[SEDE_CARATULA_RINDE['SEDE_SISTEMA_ETNOEDUCATIVO'] == "1"].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
SED_20.fillna(0,inplace=True)
SED_20.columns.name = None
SED_20.reset_index(inplace=True)
SED_20.rename(columns={'ï»¿SEDE_CODIGO':'SED_20'},
                   inplace=True)
df = pd.merge(df, SED_20, how='left',on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
df['SED_21']= df['SED_20'] / df['SED_16']
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
SEDE_PLANTAS
SEDE_PLANTAS_merge = pd.merge(SEDE_PLANTAS, SEDE_CARATULA_P[['ï»¿SEDE_CODIGO','CODIGOINTERNOMUNI','MUNI']], on='ï»¿SEDE_CODIGO')
SEDE_PLANTAS_merge
# Out:
#        ï»¿SEDE_CODIGO  PERIODO_ID  PERIODO_ANIO SEDE_TIPO       TIPO  \
# 0        105001000001           6          2019         P  Principal
# 1        105001000027           6          2019         A   Adscrita
# 2        105001000043           6          2019         P  Principal
# 3        105001000078           6          2019         A   Adscrita
# 4        105001000094           6          2019
# ...               ...         ...           ...       ...        ...
# 53488    499773000322           6          2019         A   Adscrita
# 53489    499773000683           6          2019         A   Adscrita
# 53490    294001001314           6          2019         A   Adscrita
# 53491    294001001322           6          2019         A   Adscrita
# 53492    294001001331           6          2019         A   Adscrita
#
#       SEDE_CANTIDAD_ADSCRITA SEDE_CODIGO_PRINCIPAL  \
# 0                          0
# 1                                     105001019925
# ...

# %%
SED_23=SEDE_PLANTAS_merge[SEDE_PLANTAS_merge['TIPO'] == "Adscrita"].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
SED_23.fillna(0,inplace=True)
SED_23.columns.name = None
SED_23.reset_index(inplace=True)
SED_23.rename(columns={'ï»¿SEDE_CODIGO':'SED_23'},
                   inplace=True)
df = pd.merge(df, SED_23,how='left', on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
SED_24=SEDE_PLANTAS_merge[SEDE_PLANTAS_merge['TIPO'] == "Principal"].groupby('MUNI')[['ï»¿SEDE_CODIGO']].nunique()
SED_24.fillna(0,inplace=True)
SED_24.columns.name = None
SED_24.reset_index(inplace=True)
SED_24.rename(columns={'ï»¿SEDE_CODIGO':'SED_24'},
                   inplace=True)
df = pd.merge(df, SED_24,how='left', on='MUNI')

df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1031  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1032         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1033         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1034         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1035          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
#df = pd.merge(df, SEDE_CARATULA_P[['CODIGOINTERNOMUNI','MUNI']],how='inner',on='MUNI')
#df

# %%
SEDE_MUNICIPIO=SEDE_CARATULA[['CODIGOINTERNOMUNI','MUNI']].copy()
SEDE_MUNICIPIO.drop_duplicates(keep='first', inplace=True)
SEDE_MUNICIPIO
# Out:
#        CODIGOINTERNOMUNI              MUNI
# 0                  70771             Sucre
# 6                  70820  Santiago de Tolú
# 15                 70221           Coveñas
# 17                 76001              Cali
# 21                 73001            Ibagué
# ...                  ...               ...
# 49098              50110  Barranca de Upía
# 49589              50270         El Dorado
# 56651              97161            Carurú
# 56747              97889          Yavaraté
# 56998              23815            Tuchín
#
# [1121 rows x 2 columns]

# %%
df = pd.merge(df,SEDE_MUNICIPIO, how='left',on='MUNI')
df
# Out:
#                MUNI  SED_01  SED_05   SED_02  SED_04  SED_03  SED_06  SED_07  \
# 0         Abejorral     0.0    39.0   2286.0     0.0     0.0   977.0       3
# 1          Abriaquí     0.0     0.0    333.0     0.0     0.0    19.0       2
# 2           Acacías  2563.0   424.0  12572.0   158.0  3385.0   297.0       6
# 3            Acandí     0.0     0.0   1229.0   208.0   181.0  1962.0       4
# 4           Acevedo     0.0   190.0   4988.0   376.0     0.0  2179.0       4
# ...             ...     ...     ...      ...     ...     ...     ...     ...
# 1116  Zona Bananera     0.0    40.0  15889.0  2388.0  4535.0   497.0       5
# 1117         Ábrego     0.0   753.0   5486.0   487.0  1279.0   203.0       5
# 1118         Íquira     0.0     0.0   1451.0    87.0     0.0   787.0       3
# 1119         Úmbita     0.0     0.0    954.0     0.0     0.0   297.0       2
# 1120          Útica     0.0    35.0    514.0     0.0     0.0    86.0       3
#
# ...

# %%
cols = df.columns.tolist()
cols
# Out:
# ['MUNI',
#  'SED_01',
#  'SED_05',
#  'SED_02',
#  'SED_04',
#  'SED_03',
#  'SED_06',
#  'SED_07',
#  'SED_08',
#  'SED_09',
#  'SED_10',
#  'SED_11',
#  'SED_12',
#  'SED_13',
#  'SED_14',
#  'SED_15',
#  'TIC_01',
#  'TIC_02',
#  'TIC_03_1',
#  'TIC_03_0',
#  'TIC_04_1',
#  'TIC_04_0',
#  'TIC_05_1',
#  'TIC_05_0',
#  'TIC_06_1',
#  'TIC_06_0',
#  'TIC_07_1',
#  'TIC_07_0',
#  'TIC_08_1',
#  'TIC_08_0',
#  'TIC_10_1',
#  'TIC_10_0',
#  'TIC_11_1',
#  'TIC_11_0',
#  'SED_16',
#  'SED_17',
#  'SED_18',
#  'SED_19',
#  'SED_20',
#  'SED_21',
#  'SED_23',
#  'SED_24',
#  'CODIGOINTERNOMUNI']

# %%
df=df[['CODIGOINTERNOMUNI',
       'MUNI',
         'SED_01',
         'SED_05',
         'SED_02',
         'SED_04',
         'SED_03',
         'SED_06',
         'SED_07',
         'SED_08',
         'SED_09',
         'SED_10',
         'SED_11',
         'SED_12',
         'SED_13',
         'SED_14',
         'SED_15',
         'TIC_01',
         'TIC_02',
         'TIC_03_1',
         'TIC_03_0',
         'TIC_04_1',
         'TIC_04_0',
         'TIC_05_1',
         'TIC_05_0',
         'TIC_06_1',
         'TIC_06_0',
         'TIC_07_1',
         'TIC_07_0',
         'TIC_08_1',
         'TIC_08_0',
         'TIC_10_1',
         'TIC_10_0',
         'TIC_11_1',
         'TIC_11_0',
         'SED_16',
         'SED_17',
         'SED_18',
         'SED_19',
         'SED_20',
         'SED_21',
         'SED_23',
         'SED_24']]
df
# Out:
#       CODIGOINTERNOMUNI           MUNI  SED_01  SED_05   SED_02  SED_04  \
# 0                  5002      Abejorral     0.0    39.0   2286.0     0.0
# 1                  5004       Abriaquí     0.0     0.0    333.0     0.0
# 2                 50006        Acacías  2563.0   424.0  12572.0   158.0
# 3                 27006         Acandí     0.0     0.0   1229.0   208.0
# 4                 41006        Acevedo     0.0   190.0   4988.0   376.0
# ...                 ...            ...     ...     ...      ...     ...
# 1116              47980  Zona Bananera     0.0    40.0  15889.0  2388.0
# 1117              54003         Ábrego     0.0   753.0   5486.0   487.0
# 1118              41357         Íquira     0.0     0.0   1451.0    87.0
# 1119              15842         Úmbita     0.0     0.0    954.0     0.0
# 1120              25851          Útica     0.0    35.0    514.0     0.0
#
#       SED_03  SED_06  SED_07  SED_08  ...  TIC_11_1  TIC_11_0  SED_16  SED_17  \
# ...

# %%
df.to_csv('VariablesCarlos.csv',  sep='\t' , encoding = "ISO-8859-1")
