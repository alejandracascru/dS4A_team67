# %%
import pandas as pd
import requests
from io import StringIO
#!pip install pandasql
import pandasql as ps
import time
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno 
import plotly.express as px

# %%
#sharing url from the csv file
orig_url='https://drive.google.com/file/d/19ExSzN89rNzl65mwL1EA1TJvGchY5KVy/view?usp=sharing'
file_id = orig_url.split('/')[-2]
dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
url = requests.get(dwn_url).text
csv_raw = StringIO(url)
info_departamentos  = pd.read_csv(csv_raw,sep=";")

# %% [markdown]
# Missing analysis

# %%
msno.bar(info_departamentos, labels=True, figsize=(25,6), fontsize=8)

# %%
info_departamentos_nomiss=info_departamentos.dropna().copy()
#Creacion de porcentajes
info_departamentos_nomiss['%NP_HOMBRES']=round(info_departamentos_nomiss['NP_HOMBRES']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_MUJERES']=round(info_departamentos_nomiss['NP_MUJERES']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EDAD_0_5']=round(info_departamentos_nomiss['NP_EDAD_0_5']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EDAD_6_11']=round(info_departamentos_nomiss['NP_EDAD_6_11']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EDAD_12_17']=round(info_departamentos_nomiss['NP_EDAD_12_17']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EDAD_18_28']=round(info_departamentos_nomiss['NP_EDAD_18_28']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EDAD_29_59']=round(info_departamentos_nomiss['NP_EDAD_29_59']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EDAD_60_M']=round(info_departamentos_nomiss['NP_EDAD_60_M']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EST_CIVIL_UL_C']=round(info_departamentos_nomiss['NP_EST_CIVIL_UL_C']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_EST_CIVIL_V_S_SO']=round(info_departamentos_nomiss['NP_EST_CIVIL_V_S_SO']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_AF_SALUD_ISS']=round(info_departamentos_nomiss['NP_AF_SALUD_ISS']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_AF_SALUD_REG_ESP']=round(info_departamentos_nomiss['NP_AF_SALUD_REG_ESP']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_AF_SALUD_CONTRI']=round(info_departamentos_nomiss['NP_AF_SALUD_CONTRI']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_AF_SALUD_SUBSI']=round(info_departamentos_nomiss['NP_AF_SALUD_SUBSI']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_ASISTE_CNTR_EDU']=round(info_departamentos_nomiss['NP_ASISTE_CNTR_EDU']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_NO_ASISTE_CNTR_EDU']=round(info_departamentos_nomiss['NP_NO_ASISTE_CNTR_EDU']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_NIV_EDUC_NADA']=round(info_departamentos_nomiss['NP_NIV_EDUC_NADA']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_NIV_EDUC_PRIM']=round(info_departamentos_nomiss['NP_NIV_EDUC_PRIM']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_NIV_EDUC_SEC']=round(info_departamentos_nomiss['NP_NIV_EDUC_SEC']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_NIV_EDUC_TEC']=round(info_departamentos_nomiss['NP_NIV_EDUC_TEC']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_ACT_U_MES_NADA']=round(info_departamentos_nomiss['NP_ACT_U_MES_NADA']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_ACT_U_MES_TRAB']=round(info_departamentos_nomiss['NP_ACT_U_MES_TRAB']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_ACT_U_MES_BUSC_TRAB']=round(info_departamentos_nomiss['NP_ACT_U_MES_BUSC_TRAB']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_ACT_U_MES_ESTU']=round(info_departamentos_nomiss['NP_ACT_U_MES_ESTU']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_ACT_U_MES_PENS']=round(info_departamentos_nomiss['NP_ACT_U_MES_PENS']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_INGRESOS_SI']=round(info_departamentos_nomiss['NP_INGRESOS_SI']/info_departamentos_nomiss['NP_PERSONAS'],4)
info_departamentos_nomiss['%NP_INGRESOS_NO']=round(info_departamentos_nomiss['NP_INGRESOS_NO']/info_departamentos_nomiss['NP_PERSONAS'],4)

info_departamentos_nomiss['%NH_ARRIENDO']=round(info_departamentos_nomiss['NH_ARRIENDO']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_PROPIA_PAGA']=round(info_departamentos_nomiss['NH_PROPIA_PAGA']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_HOG_PROPIA_NO_PAGA']=round(info_departamentos_nomiss['NH_HOG_PROPIA_NO_PAGA']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_HOG_OTRA']=round(info_departamentos_nomiss['NH_HOG_OTRA']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_SANIT_ALCANT']=round(info_departamentos_nomiss['NH_SANIT_ALCANT']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_SANIT_POZO_S']=round(info_departamentos_nomiss['NH_SANIT_POZO_S']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_SANIT_NO_ALC_POS']=round(info_departamentos_nomiss['NH_SANIT_NO_ALC_POS']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_SANIT_LETRI']=round(info_departamentos_nomiss['NH_SANIT_LETRI']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_ACUED']=round(info_departamentos_nomiss['NH_AGUA_ACUED']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_POZ_BOMB']=round(info_departamentos_nomiss['NH_AGUA_POZ_BOMB']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_POZ_NO_BOMB']=round(info_departamentos_nomiss['NH_AGUA_POZ_NO_BOMB']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_POZ_LLUV']=round(info_departamentos_nomiss['NH_AGUA_POZ_LLUV']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_POZ_RIO']=round(info_departamentos_nomiss['NH_AGUA_POZ_RIO']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_PILA_PUB']=round(info_departamentos_nomiss['NH_AGUA_PILA_PUB']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_CARROT']=round(info_departamentos_nomiss['NH_AGUA_CARROT']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_AGUAT']=round(info_departamentos_nomiss['NH_AGUA_AGUAT']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_AGUA_DONAC']=round(info_departamentos_nomiss['NH_AGUA_DONAC']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMB_COC_ELECT']=round(info_departamentos_nomiss['NH_COMB_COC_ELECT']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMB_COC_GAS_N']=round(info_departamentos_nomiss['NH_COMB_COC_GAS_N']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMB_COC_GAS_P']=round(info_departamentos_nomiss['NH_COMB_COC_GAS_P']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMB_COC_KEROS']=round(info_departamentos_nomiss['NH_COMB_COC_KEROS']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMB_COC_CARB']=round(info_departamentos_nomiss['NH_COMB_COC_CARB']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMB_COC_DESECH']=round(info_departamentos_nomiss['NH_COMB_COC_DESECH']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_LUZ_ELECT']=round(info_departamentos_nomiss['NH_LUZ_ELECT']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_LUZ_SOLAR']=round(info_departamentos_nomiss['NH_LUZ_SOLAR']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_LUZ_KEROS']=round(info_departamentos_nomiss['NH_LUZ_KEROS']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_LUZ_VELA']=round(info_departamentos_nomiss['NH_LUZ_VELA']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_TV_SI']=round(info_departamentos_nomiss['NH_TV_SI']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_TV_NO']=round(info_departamentos_nomiss['NH_TV_NO']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_TV_CABLE_SI']=round(info_departamentos_nomiss['NH_TV_CABLE_SI']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_TV_CABLE_NO']=round(info_departamentos_nomiss['NH_TV_CABLE_NO']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMPU_SI']=round(info_departamentos_nomiss['NH_COMPU_SI']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_COMPU_NO']=round(info_departamentos_nomiss['NH_COMPU_NO']/info_departamentos_nomiss['NH_HOGARES'],4)
info_departamentos_nomiss['%NH_PERSONAS']=round(info_departamentos_nomiss['NH_PERSONAS']/info_departamentos_nomiss['NH_HOGARES'],4)

info_departamentos_nomiss['%NV_CASA_APTO']=round(info_departamentos_nomiss['NV_CASA_APTO']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_CUARTO']=round(info_departamentos_nomiss['NV_CUARTO']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_OTRO']=round(info_departamentos_nomiss['NV_OTRO']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_CASA_INDIG']=round(info_departamentos_nomiss['NV_CASA_INDIG']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_TIENE_LUZ']=round(info_departamentos_nomiss['NV_TIENE_LUZ']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_NO_TIENE_LUZ']=round(info_departamentos_nomiss['NV_NO_TIENE_LUZ']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_TIENE_ALCANT']=round(info_departamentos_nomiss['NV_TIENE_ALCANT']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_NO_TIENE_ALCANT']=round(info_departamentos_nomiss['NV_NO_TIENE_ALCANT']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_TIENE_TELEF']=round(info_departamentos_nomiss['NV_TIENE_TELEF']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_NO_TIENE_TELEF']=round(info_departamentos_nomiss['NV_NO_TIENE_TELEF']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_TIENE_ACUEDU']=round(info_departamentos_nomiss['NV_TIENE_ACUEDU']/info_departamentos_nomiss['NV_VIVIENDAS'],4)
info_departamentos_nomiss['%NV_NO_TIENE_ACUEDU']=round(info_departamentos_nomiss['NV_NO_TIENE_ACUEDU']/info_departamentos_nomiss['NV_VIVIENDAS'],4)

# %%
corr=info_departamentos_nomiss[info_departamentos_nomiss.columns[1:]].corr()['DESERTION_PERC'][:].reset_index(name='LINEAR_CORRELATION')
corr=corr.reindex(corr.LINEAR_CORRELATION.abs().sort_values(ascending=False).index)
corr=corr.loc[corr['index']!= 'DESERTION_PERC']
corr=corr.loc[abs(corr['LINEAR_CORRELATION'])>0.2]

plt.figure(figsize=(20, 5))
b = sns.barplot(x="index", y="LINEAR_CORRELATION", data=corr,capsize=5,palette="Blues_d")
b.axes.set_title("Correlation of SISBEN's variables with Drop-out rate",fontsize=20)
b.set_xticklabels(b.get_xticklabels(), rotation=45, horizontalalignment='right')
b.set_xlabel("Variable",fontsize=15)
b.tick_params(labelsize=9)
b.set_ylabel("")

corr_1=info_departamentos_nomiss[info_departamentos_nomiss.columns[1:]].corr()['DESERTION_NO'][:].reset_index(name='LINEAR_CORRELATION')
corr_1=corr_1.reindex(corr_1.LINEAR_CORRELATION.abs().sort_values(ascending=False).index)
corr_1=corr_1.loc[corr_1['index']!= 'DESERTION_NO']
corr_1=corr_1.loc[abs(corr_1['LINEAR_CORRELATION'])>0.5]

plt.figure(figsize=(20, 5))
b = sns.barplot(x="index", y="LINEAR_CORRELATION", data=corr_1,capsize=5,palette="Blues_d")
b.axes.set_title("Correlation of SISBEN's variables with Drop-out number of cases",fontsize=20)
b.set_xticklabels(b.get_xticklabels(), rotation=45, horizontalalignment='right')
b.set_xlabel("Variable",fontsize=15)
b.tick_params(labelsize=9)
b.set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax = sns.lineplot(x="ANIO", y="%NH_COMPU_NO",hue="DEPT_NOMBRE", data=info_departamentos_nomiss)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
fig = px.scatter(info_departamentos_nomiss, x="NV_CUARTO", y="DESERTION_NO", animation_frame="ANIO",hover_name="DEPT_NOMBRE")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="88c4d410-fc4c-4005-9c32-228e88d355d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88c4d410-fc4c-4005-9c32-228e88d355d3")) {
#                     Plotly.newPlot(
#                         '88c4d410-fc4c-4005-9c32-228e88d355d3',
# ...

# %%
fig = px.scatter(info_departamentos_nomiss, x="NV_CUARTO", y="DESERTION_PERC", animation_frame="ANIO",hover_name="DEPT_NOMBRE")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="81a8105e-5d60-41b5-aead-ea2cf693ef4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81a8105e-5d60-41b5-aead-ea2cf693ef4c")) {
#                     Plotly.newPlot(
#                         '81a8105e-5d60-41b5-aead-ea2cf693ef4c',
# ...

# %%
#info_departamentos_2016=info_departamentos.loc[info_departamentos['corte_anio']==2016]
#info_departamentos_2016['%Hombres']=round(info_departamentos_2016['PER001_1']/info_departamentos_2016['PER001_T'],2)
#info_departamentos_2016['%Mujeres']=round(info_departamentos_2016['PER001_2']/info_departamentos_2016['PER001_T'],2)
#info_departamentos_2016.head()
#info_departamentos_2016=info_departamentos_2016.sort_values(by=['%Mujeres'],ascending=False)
#barlist=info_departamentos_2016.plot.bar(x = 'depto_nombre', y = ['%Hombres', '%Mujeres'], rot = 40,figsize=(15,3), color = ['b','r'])

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])

fig["layout"].pop("updatemenus") # optional, drop animation buttons
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ca4e0760-c924-402c-a973-326e6925e169" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca4e0760-c924-402c-a973-326e6925e169")) {
#                     Plotly.newPlot(
#                         'ca4e0760-c924-402c-a973-326e6925e169',
# ...
